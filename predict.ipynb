# %% [markdown]
# ## Demo and test geocodenet model

# %%
# !apt-get install libgeos-3.5.0
# !apt-get install libgeos-dev
# !pip install https://github.com/matplotlib/basemap/archive/master.zip
# !pip install pyproj==1.9.6

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
def print_geopoint(p):
    lon, lat = p
    print(lon * 360 - 180, lat * 180 - 90)
    
q = "0 Chemin des Hautes Varennes 45200	Montargis".lower()
Q = str_to_indexes(q, max_address_length)
print(Q.shape)

print(Q)
for r in model.predict(np.array([Q])):
    print_geopoint(r)

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution=None, width=8E6, height=8E6, lat_0=48, lon_0=2,)
m.etopo(scale=1, alpha=0.5)

# Map (long, lat) to (x, y) for plotting
x, y = m(48.004106283187866, 2.4272918701171875)
plt.plot(x, y, 'ok', markersize=5)
plt.text(x, y, ' Seattle', fontsize=12);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
